# %% [markdown]
# # Deep Learning Classifier
#
# ### Achievement
# Using a deep neural network in combination with hyperparameter search, we obtain a binary classifier able to distinguish benign from malicious network traffic with the following performance characteristics:
#
# |PR Score|Precision Positive|Recall Positive|False-Positives|False-Negatives|
# |---|---|---|---|---|
# |0.97816|0.967|0.954|8966|12629|
#
#
# ## 1. Introduction
#
# In this notebook, we will pursue a supervised learning approach, to create a binary classifier that is able to distinguish benign from malicious network traffic.
# We will train multiple deep neural network models, using the network traffic data taken from the [CIC-IDS-2018 dataset](https://www.unb.ca/cic/datasets/ids-2018.html), and will evaluate their respective performance.
# For this purpose, values of the target variable of the dataset are grouped into two classes,  benign and attack, with the attack class subsuming all types of malicious network traffic. As the dataset is severly imbalanced, containing 83% of benign and only 27% of malicious samples, we will have to take this class imbalance into account during training.
#
# In the first part of the notebook, we train a rather simple deep network, using two different approaches.
# The first approach does not take class imbalance into account, while the second approach uses the class weights to weight the losses of the under-represented samples more heavily during training.
# Comparing the results of both training runs, we decide on using one of the two approaches going forward.
#
# In the second part of the notebook, we concern ourselves with finding the optimal model architecture and parameter configuration for the classifier, by employing hyperparameter optimization using the [Hyperopt](https://github.com/hyperopt/hyperopt) library.
#
# The deep learning models are trained using the [Keras](https://keras.io/) library, employing [Tensorflow 2](https://www.tensorflow.org/) as the auto-differentiation framework in the backend.

# %% [markdown]
# ## 2. Dataset Preparation
#
# In this section we load the dataset and prepare the data for training. The preprocessed dataset from CIC-IDS-2018 can be found at [Google Drive](https://drive.google.com/open?id=1HrTPh0YRSZ4T9DLa_c47lubheKUcPl0r).

# %%
dataset_base_path = r'/home/rahul/development/ml-ids/raw_dataset/'
import tensorflow as tf
import tensorflow as tf
if tf.test.gpu_device_name():
    print('Default GPU Device Details: {}'.format(tf.test.gpu_device_name()))
else:
    print("Please install Tensorflow that supports GPU")
physical_devices = tf.config.experimental.list_physical_devices('GPU')
physical_devices
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
tf.test.is_gpu_available()
# tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# Please install Tensorflow that supports GPU
# Num GPUs Available:  0
# 2022-07-09 14:55:02.497238: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2022-07-09 14:55:02.532276: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2096074999 Hz
# 2022-07-09 14:55:02.533206: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55cc9376e120 executing computations on platform Host. Devices:
# 2022-07-09 14:55:02.533243: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Host, Default Version
# 2022-07-09 14:55:02.536363: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-07-09 14:55:02.536426: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-07-09 14:55:02.536486: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (nitro): /proc/driver/nvidia/version does not exist
# False

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import gc
import shap
from ml_ids.data.dataset import load_dataset
from ml_ids.data.metadata import FEATURES_NO_VARIANCE
from ml_ids.visualization import plot_hist, print_binary_performance, plot_pr_curve
from ml_ids.keras.metrics import AveragePrecisionScoreMetric
from ml_ids.keras.evaluation import evaluate_model
from ml_ids.keras.prediction import predict, predict_proba
from ml_ids.tf_utils import enable_gpu_memory_growth
from notebook_utils import transform_data
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from tensorflow import keras
from tensorflow.keras import layers, models, optimizers, callbacks, regularizers, metrics
from collections import Counter
from hyperopt import fmin, hp, tpe, atpe, Trials, STATUS_OK
from hyperopt.plotting import main_plot_history, main_plot_vars
import uuid

K = keras.backend

rand_state = 42
tf.random.set_seed(rand_state)
np.random.seed(rand_state)

# enable_gpu_memory_growth()

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### 2.1 Data Loading & Preparation
#
# In this part we load the dataset, specifing the features to omit. These encompass all features having no variance and features which should not be taken into account, in order to obtain a better generalization of the model.
#
# We use `median` imputation as the strategy to impute missing values, as the distributions of all features, for which imputation is necessary, are highly skewed.
# Futhermore, we scale the data using a `StandardScaler` and upsample the malicious network traffic to obtain  `100000` samples per attack category. We perform upsampling by using the technique of Synthetic Minority Over-sampling provided by the [SMOTE](https://imbalanced-learn.readthedocs.io/en/stable/generated/imblearn.over_sampling.SMOTE.html) library.
#
# Furthermore, the dataset is splitted into:
# * training set,
# * validation set and
# * test set.

# %%
dataset = load_dataset(dataset_base_path,
                       omit_cols=FEATURES_NO_VARIANCE + ['timestamp', 'dst_port', 'protocol'],
                       nrows=10000,
                       preserve_neg_value_cols=['init_fwd_win_byts', 'init_bwd_win_byts'])

X_train, y_train, X_val, y_val, X_test, y_test, column_names = transform_data(dataset=dataset,
                                                                              imputer_strategy='median',
                                                                              scaler=StandardScaler,
                                                                              attack_samples=100000,
                                                                              random_state=rand_state)

del dataset
# Out:
# Samples:
# ========
# Training: (80000, 68)
# Val:      (10000, 68)
# Test:     (10000, 68)
#
# Training labels:
# ================
# Benign                      34467
# DDoS attacks-LOIC-HTTP       7947
# DoS attacks-GoldenEye        7945
# FTP-BruteForce               7923
# DoS attacks-SlowHTTPTest     7919
# Bot                          6816
# DDOS attack-HOIC             4856
# DDOS attack-LOIC-UDP         1384
# Brute Force -Web              489
# Brute Force -XSS              184
# SQL Injection                  70
# Name: label, dtype: int64
#
# Validation labels:
# ==================
# Benign                      4308
# DDoS attacks-LOIC-HTTP       994
# DoS attacks-GoldenEye        993
# FTP-BruteForce               990
# DoS attacks-SlowHTTPTest     990
# Bot                          852
# DDOS attack-HOIC             607
# DDOS attack-LOIC-UDP         173
# Brute Force -Web              61
# Brute Force -XSS              23
# SQL Injection                  9
# Name: label, dtype: int64
#
# Test labels:
# ============
# Benign                      4309
# DDoS attacks-LOIC-HTTP       993
# DoS attacks-GoldenEye        993
# FTP-BruteForce               991
# DoS attacks-SlowHTTPTest     990
# Bot                          852
# DDOS attack-HOIC             607
# DDOS attack-LOIC-UDP         173
# Brute Force -Web              61
# Brute Force -XSS              23
# SQL Injection                  8
# Name: label, dtype: int64
# Samples:
# ========
# Training: (80000, 68)
# Val:      (10000, 68)
# Test:     (10000, 68)
#
# Missing values:
# ===============
# Training: 0
# Val:      0
# Test:     0
#
# Scaling:
# ========
# Training: min=-2.292170602830406, max=220.82481911795813
# Val:      min=-2.292170602830406, max=68.2892989542701
# Test:     min=-2.292170602830406, max=133.168397579893
# /home/rahul/anaconda3/envs/ml-ids-notebooks/lib/python3.7/site-packages/imblearn/utils/_validation.py:253: UserWarning: After over-sampling, the number of samples (100000) in class 0 will be larger than the number of samples in the majority class (class #0 -> 34467)
#   n_samples_majority))
# /home/rahul/anaconda3/envs/ml-ids-notebooks/lib/python3.7/site-packages/imblearn/utils/_validation.py:253: UserWarning: After over-sampling, the number of samples (100000) in class 1 will be larger than the number of samples in the majority class (class #0 -> 34467)
#   n_samples_majority))
# /home/rahul/anaconda3/envs/ml-ids-notebooks/lib/python3.7/site-packages/imblearn/utils/_validation.py:253: UserWarning: After over-sampling, the number of samples (100000) in class 2 will be larger than the number of samples in the majority class (class #0 -> 34467)
#   n_samples_majority))
# /home/rahul/anaconda3/envs/ml-ids-notebooks/lib/python3.7/site-packages/imblearn/utils/_validation.py:253: UserWarning: After over-sampling, the number of samples (100000) in class 3 will be larger than the number of samples in the majority class (class #0 -> 34467)
#   n_samples_majority))
# /home/rahul/anaconda3/envs/ml-ids-notebooks/lib/python3.7/site-packages/imblearn/utils/_validation.py:253: UserWarning: After over-sampling, the number of samples (100000) in class 4 will be larger than the number of samples in the majority class (class #0 -> 34467)
#   n_samples_majority))
# /home/rahul/anaconda3/envs/ml-ids-notebooks/lib/python3.7/site-packages/imblearn/utils/_validation.py:253: UserWarning: After over-sampling, the number of samples (100000) in class 6 will be larger than the number of samples in the majority class (class #0 -> 34467)
#   n_samples_majority))
# /home/rahul/anaconda3/envs/ml-ids-notebooks/lib/python3.7/site-packages/imblearn/utils/_validation.py:253: UserWarning: After over-sampling, the number of samples (100000) in class 8 will be larger than the number of samples in the majority class (class #0 -> 34467)
#   n_samples_majority))
# /home/rahul/anaconda3/envs/ml-ids-notebooks/lib/python3.7/site-packages/imblearn/utils/_validation.py:253: UserWarning: After over-sampling, the number of samples (100000) in class 9 will be larger than the number of samples in the majority class (class #0 -> 34467)
#   n_samples_majority))
# /home/rahul/anaconda3/envs/ml-ids-notebooks/lib/python3.7/site-packages/imblearn/utils/_validation.py:253: UserWarning: After over-sampling, the number of samples (100000) in class 10 will be larger than the number of samples in the majority class (class #0 -> 34467)
#   n_samples_majority))
# /home/rahul/anaconda3/envs/ml-ids-notebooks/lib/python3.7/site-packages/imblearn/utils/_validation.py:253: UserWarning: After over-sampling, the number of samples (100000) in class 11 will be larger than the number of samples in the majority class (class #0 -> 34467)
#   n_samples_majority))
# /home/rahul/anaconda3/envs/ml-ids-notebooks/lib/python3.7/site-packages/imblearn/utils/_validation.py:253: UserWarning: After over-sampling, the number of samples (100000) in class 13 will be larger than the number of samples in the majority class (class #0 -> 34467)
#   n_samples_majority))
# Samples:
# ========
# Training: (1100000, 68)
#
# Training labels:
# ================
# Counter({0: 100000, 11: 100000, 4: 100000, 10: 100000, 6: 100000, 1: 100000, 8: 100000, 9: 100000, 2: 100000, 3: 100000, 13: 100000})

# %% [markdown]
# ### 2.2 Target Grouping & Class Weight Calculation
#
# In this step we create the binary target variable by grouping all malicious network traffic into a single attack category represented by the positive class `1`, whereas benign traffic is represented as the negative class `0`.
#
# Furthermore, we calculate the weights for each class, given by the proportion of samples of this class in the training set.
# For the majority class, the class weight is `1`.
# For the minority class, the class weight is calculated with the following formula:
# \begin{align}
# \frac{(sum\_majority\_class)}{(sum\_minority\_class)} \\
# \end{align}
# In our case this translates to:
# \begin{align}
# \frac{(sum\_negative\_class)}{(sum\_positive\_class)} \\
# \end{align}

# %%
y_train_is_attack = (y_train != 0).astype('int')

minority_class_weight = len(y_train_is_attack[y_train_is_attack == 0]) / len(y_train_is_attack[y_train_is_attack == 1])

class_weights = { 
    0: 1, 
    1: minority_class_weight
}

# %% [markdown]
# ## 3. Static Model Training
#
# In this section, we train a static model, comprised of `3` layers, each containing `400` units, using the `Adam` optimizer.
# We execute two training runs. In run one we ignore the class imbalance, whereas in run two we use the class weights to take the class imblance into account.
# Afterwards we compare the results and select one approach to use for hyperparameter optimization.

# %%
def create_model(input_dims, 
                 nr_layers, 
                 nr_units, 
                 activation, 
                 kerner_initializer,
                 optimizer,
                 dropout_layer=None):
    model = models.Sequential()
    model.add(layers.Input(shape=[input_dims]))
    
    for l in range(nr_layers):
        model.add(layers.Dense(nr_units, activation=activation, kernel_initializer=kerner_initializer))
        
    if dropout_layer:
        model.add(dropout_layer)
    
    model.add(layers.Dense(1, activation='sigmoid'))
    
    model.compile(optimizer=optimizer, 
                  loss='binary_crossentropy', 
                  metrics=[metrics.AUC(curve='PR'),
                           metrics.Precision(), 
                           metrics.Recall()])
    return model

# %%
def train_static_model(X_train, y_train, X_val, y_val, model_path, class_weights=None):    
    input_dims = X_train.shape[1]
    epochs = 20
    batch_size = 4096
    
    K.clear_session()
    gc.collect()

    model = create_model(input_dims=input_dims,
                         nr_layers=3,
                         nr_units=400,
                         activation='selu',
                         kerner_initializer='lecun_normal',
                         optimizer=optimizers.Adam())

    print(model.summary())
    
    mc = callbacks.ModelCheckpoint(filepath=model_path, save_best_only=True)

    lr_scheduler = callbacks.ReduceLROnPlateau(factor=0.2, patience=3)

    hist = model.fit(x=X_train, 
                     y=y_train,
                     validation_data=(X_val, y_val),
                     batch_size=batch_size,
                     epochs=epochs,
                     class_weight=class_weights,
                     callbacks=[
                         lr_scheduler,
                         mc
                     ])
    
    return model, hist

# %% [markdown]
# ### 3.1 Static Model without class weights
#
# In this step, we train the static model withouth using class weights.

# %%
model_no_class_weights, hist = train_static_model(X_train, 
                                                  y_train_is_attack, 
                                                  X_val, 
                                                  y_val.label_is_attack.values,
                                                  'models/model_no_class_weights.h5')
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 400)               27600
# _________________________________________________________________
# dense_1 (Dense)              (None, 400)               160400
# _________________________________________________________________
# dense_2 (Dense)              (None, 400)               160400
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 401
# =================================================================
# Total params: 348,801
# Trainable params: 348,801
# Non-trainable params: 0
# _________________________________________________________________
# None
# 2022-07-09 14:56:32.266933: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 598400000 exceeds 10% of system memory.
# Train on 1100000 samples, validate on 10000 samples
# Epoch 1/20
# 1100000/1100000 [==============================] - 47s 42us/sample - loss: 0.0854 - auc: 0.9967 - precision: 0.9752 - recall: 0.9941 - val_loss: 0.1232 - val_auc: 0.9932 - val_precision: 0.8742 - val_recall: 0.9989
# Epoch 2/20
# 1100000/1100000 [==============================] - 45s 41us/sample - loss: 0.0426 - auc: 0.9990 - precision: 0.9853 - recall: 0.9956 - val_loss: 0.1430 - val_auc: 0.9865 - val_precision: 0.9199 - val_recall: 0.9921
# Epoch 3/20
# 1100000/1100000 [==============================] - 46s 42us/sample - loss: 0.0381 - auc: 0.9991 - precision: 0.9875 - recall: 0.9948 - val_loss: 0.1268 - val_auc: 0.9928 - val_precision: 0.8774 - val_recall: 0.9995
# Epoch 4/20
# 1100000/1100000 [==============================] - 47s 43us/sample - loss: 0.0353 - auc: 0.9992 - precision: 0.9881 - recall: 0.9953 - val_loss: 0.1188 - val_auc: 0.9923 - val_precision: 0.9233 - val_recall: 0.9921
# Epoch 5/20
# 1100000/1100000 [==============================] - 46s 42us/sample - loss: 0.0346 - auc: 0.9993 - precision: 0.9885 - recall: 0.9951 - val_loss: 0.1010 - val_auc: 0.9969 - val_precision: 0.9379 - val_recall: 0.9919
# Epoch 6/20
# 1100000/1100000 [==============================] - 46s 42us/sample - loss: 0.0333 - auc: 0.9995 - precision: 0.9884 - recall: 0.9953 - val_loss: 0.1129 - val_auc: 0.9966 - val_precision: 0.8899 - val_recall: 0.9996
# Epoch 7/20
# 1100000/1100000 [==============================] - 48s 44us/sample - loss: 0.0314 - auc: 0.9996 - precision: 0.9890 - recall: 0.9954 - val_loss: 0.0741 - val_auc: 0.9982 - val_precision: 0.9452 - val_recall: 0.9917
# Epoch 8/20
# 1100000/1100000 [==============================] - 45s 40us/sample - loss: 0.0309 - auc: 0.9996 - precision: 0.9894 - recall: 0.9954 - val_loss: 0.1251 - val_auc: 0.9971 - val_precision: 0.8824 - val_recall: 0.9995
# Epoch 9/20
# 1100000/1100000 [==============================] - 45s 41us/sample - loss: 0.0299 - auc: 0.9996 - precision: 0.9893 - recall: 0.9956 - val_loss: 0.0996 - val_auc: 0.9972 - val_precision: 0.9437 - val_recall: 0.9919
# Epoch 10/20
# 1100000/1100000 [==============================] - 48s 44us/sample - loss: 0.0286 - auc: 0.9996 - precision: 0.9900 - recall: 0.9960 - val_loss: 0.0929 - val_auc: 0.9972 - val_precision: 0.9325 - val_recall: 0.9921
# Epoch 11/20
# 1100000/1100000 [==============================] - 45s 41us/sample - loss: 0.0262 - auc: 0.9997 - precision: 0.9905 - recall: 0.9973 - val_loss: 0.0833 - val_auc: 0.9982 - val_precision: 0.9306 - val_recall: 0.9921
# Epoch 12/20
# 1100000/1100000 [==============================] - 46s 42us/sample - loss: 0.0257 - auc: 0.9997 - precision: 0.9905 - recall: 0.9978 - val_loss: 0.0829 - val_auc: 0.9977 - val_precision: 0.9270 - val_recall: 0.9995
# Epoch 13/20
# 1100000/1100000 [==============================] - 48s 44us/sample - loss: 0.0254 - auc: 0.9997 - precision: 0.9905 - recall: 0.9978 - val_loss: 0.0763 - val_auc: 0.9972 - val_precision: 0.9312 - val_recall: 0.9921
# Epoch 14/20
# 1100000/1100000 [==============================] - 48s 44us/sample - loss: 0.0249 - auc: 0.9997 - precision: 0.9905 - recall: 0.9991 - val_loss: 0.0798 - val_auc: 0.9984 - val_precision: 0.9304 - val_recall: 0.9984
# Epoch 15/20
# 1100000/1100000 [==============================] - 47s 43us/sample - loss: 0.0248 - auc: 0.9997 - precision: 0.9905 - recall: 0.9992 - val_loss: 0.0858 - val_auc: 0.9981 - val_precision: 0.9272 - val_recall: 0.9995
# Epoch 16/20
# 1100000/1100000 [==============================] - 47s 42us/sample - loss: 0.0247 - auc: 0.9997 - precision: 0.9905 - recall: 0.9992 - val_loss: 0.0860 - val_auc: 0.9982 - val_precision: 0.9249 - val_recall: 0.9995
# Epoch 17/20
# 1100000/1100000 [==============================] - 46s 42us/sample - loss: 0.0246 - auc: 0.9997 - precision: 0.9906 - recall: 0.9997 - val_loss: 0.0821 - val_auc: 0.9982 - val_precision: 0.9300 - val_recall: 0.9986
# Epoch 18/20
# 1100000/1100000 [==============================] - 46s 42us/sample - loss: 0.0245 - auc: 0.9997 - precision: 0.9906 - recall: 0.9997 - val_loss: 0.0855 - val_auc: 0.9984 - val_precision: 0.9275 - val_recall: 0.9995
# Epoch 19/20
# 1100000/1100000 [==============================] - 47s 42us/sample - loss: 0.0245 - auc: 0.9997 - precision: 0.9906 - recall: 0.9997 - val_loss: 0.0865 - val_auc: 0.9982 - val_precision: 0.9273 - val_recall: 0.9995
# Epoch 20/20
# 1100000/1100000 [==============================] - 50s 46us/sample - loss: 0.0245 - auc: 0.9997 - precision: 0.9906 - recall: 0.9997 - val_loss: 0.0842 - val_auc: 0.9982 - val_precision: 0.9264 - val_recall: 0.9995

# %% [markdown]
# [Output omitted for brevity]

# %% [markdown]
# ### Validation
#
# Inspecting the metrics and learning curves, we observe that the model does not overfit the training set.

# %%
model_no_class_weights = models.load_model('models/model_no_class_weights.h5')
evaluate_model(model_no_class_weights, 
               X_train, 
               y_train_is_attack,
               X_val, y_val.label_is_attack.values, 
               metric_title='Loss / PR AUC / Precision / Recall')
# Out:
# Evaluation:
# ===========
#        Loss / PR AUC / Precision / Recall
# 2022-07-09 15:38:32.044369: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 598400000 exceeds 10% of system memory.
# Train: [0.03088931940452619, 0.9996559, 0.9935008, 0.989957]
# Val:   [0.07410237938165665, 0.99816066, 0.9452445, 0.9917428]

# %%
fix, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(20, 8))

plot_hist(hist, ax=ax1)
plot_hist(hist, metrics=['auc', 'val_auc'], ax=ax2)
plot_hist(hist, metrics=['precision', 'val_precision'], ax=ax3)
plot_hist(hist, metrics=['recall', 'val_recall'], ax=ax4)

# %% [markdown]
# ### Performance
#
# The performance of the model is quite compelling with a PR score of `0.97718`.
# Looking at the classification report we notice that the precision of the positive class is quite high (`0.992`), while having a lower recall (`0.939`). This effect is most likely caused by the overwhelming amount of samples from the negative class in the training set.
# Consequently, the confusion matrix reveals a low amount of false-positives (`1956` samples) but a high amount of false-negatives (`16898` samples).
# The misclassification statistic shows that the majority of false-negative results originate from the attack category of `Infiltration`, with a misclassification rate of `98%`.

# %%
pred_val_score = predict_proba(model_no_class_weights, X_val)
plot_pr_curve(y_val.label_is_attack.values, pred_val_score)
# Out:
# Average PR Score 0.9990576578380777

# %%
pred_val = predict(model_no_class_weights, X_val)
print_binary_performance(y_val, y_val.label_is_attack, pred_val)
# Out:
# Classification Report:
# ======================
#               precision    recall  f1-score   support
#
#            0      0.988     0.924     0.955      4308
#            1      0.945     0.992     0.968      5692
#
#     accuracy                          0.963     10000
#    macro avg      0.967     0.958     0.962     10000
# weighted avg      0.964     0.963     0.962     10000
#
# Confusion Matrix:
# =================
# Misclassifications by attack category:
# ======================================
#                        misclassified  total  percent_misclassified
# Benign                           327   4308               0.075905
# Bot                               43    852               0.050469
# Brute Force -Web                   3     61               0.049180
# DoS attacks-GoldenEye              1    993               0.001007

# %% [markdown]
# ### 3.2 Static Model using class weights
#
# In this step, we train the static model using class weights to take the class imbalance into account.

# %%
model_class_weights, hist = train_static_model(X_train, 
                                               y_train_is_attack, 
                                               X_val, 
                                               y_val.label_is_attack.values,
                                               'models/model_class_weight.h5',
                                               class_weights)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 400)               27600
# _________________________________________________________________
# dense_1 (Dense)              (None, 400)               160400
# _________________________________________________________________
# dense_2 (Dense)              (None, 400)               160400
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 401
# =================================================================
# Total params: 348,801
# Trainable params: 348,801
# Non-trainable params: 0
# _________________________________________________________________
# None
# 2022-07-09 15:40:13.942953: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 598400000 exceeds 10% of system memory.
# Train on 1100000 samples, validate on 10000 samples
# Epoch 1/20
# 1100000/1100000 [==============================] - 47s 43us/sample - loss: 0.0270 - auc: 0.9985 - precision: 0.9933 - recall: 0.9399 - val_loss: 0.0301 - val_auc: 0.9957 - val_precision: 0.9887 - val_recall: 0.9877
# Epoch 2/20
# 1100000/1100000 [==============================] - 48s 44us/sample - loss: 0.0149 - auc: 0.9993 - precision: 0.9983 - recall: 0.9618 - val_loss: 0.0416 - val_auc: 0.9982 - val_precision: 0.9858 - val_recall: 0.9893
# Epoch 3/20
# 1100000/1100000 [==============================] - 46s 42us/sample - loss: 0.0118 - auc: 0.9997 - precision: 0.9986 - recall: 0.9672 - val_loss: 0.0338 - val_auc: 0.9981 - val_precision: 0.9935 - val_recall: 0.9896
# Epoch 4/20
# 1100000/1100000 [==============================] - 50s 45us/sample - loss: 0.0105 - auc: 0.9997 - precision: 0.9991 - recall: 0.9672 - val_loss: 0.0205 - val_auc: 0.9985 - val_precision: 0.9956 - val_recall: 0.9893
# Epoch 5/20
# 1100000/1100000 [==============================] - 45s 41us/sample - loss: 0.0097 - auc: 0.9997 - precision: 0.9994 - recall: 0.9678 - val_loss: 0.0184 - val_auc: 0.9991 - val_precision: 0.9958 - val_recall: 0.9891
# Epoch 6/20
# 1100000/1100000 [==============================] - 46s 41us/sample - loss: 0.0205 - auc: 0.9989 - precision: 0.9971 - recall: 0.9576 - val_loss: 0.0394 - val_auc: 0.9961 - val_precision: 0.9908 - val_recall: 0.9879
# Epoch 7/20
# 1100000/1100000 [==============================] - 47s 43us/sample - loss: 0.0129 - auc: 0.9993 - precision: 0.9991 - recall: 0.9670 - val_loss: 0.0306 - val_auc: 0.9951 - val_precision: 0.9926 - val_recall: 0.9898
# Epoch 8/20
# 1100000/1100000 [==============================] - 45s 41us/sample - loss: 0.0109 - auc: 0.9996 - precision: 0.9992 - recall: 0.9677 - val_loss: 0.0394 - val_auc: 0.9972 - val_precision: 0.9930 - val_recall: 0.9898
# Epoch 9/20
# 1100000/1100000 [==============================] - 43s 39us/sample - loss: 0.0096 - auc: 0.9998 - precision: 0.9994 - recall: 0.9682 - val_loss: 0.0252 - val_auc: 0.9988 - val_precision: 0.9930 - val_recall: 0.9900
# Epoch 10/20
# 1100000/1100000 [==============================] - 44s 40us/sample - loss: 0.0092 - auc: 0.9998 - precision: 0.9994 - recall: 0.9682 - val_loss: 0.0239 - val_auc: 0.9987 - val_precision: 0.9930 - val_recall: 0.9900
# Epoch 11/20
# 1100000/1100000 [==============================] - 45s 41us/sample - loss: 0.0090 - auc: 0.9998 - precision: 0.9994 - recall: 0.9682 - val_loss: 0.0249 - val_auc: 0.9988 - val_precision: 0.9949 - val_recall: 0.9900
# Epoch 12/20
# 1100000/1100000 [==============================] - 49s 45us/sample - loss: 0.0087 - auc: 0.9998 - precision: 0.9995 - recall: 0.9683 - val_loss: 0.0229 - val_auc: 0.9988 - val_precision: 0.9954 - val_recall: 0.9900
# Epoch 13/20
# 1100000/1100000 [==============================] - 43s 39us/sample - loss: 0.0087 - auc: 0.9998 - precision: 0.9996 - recall: 0.9683 - val_loss: 0.0226 - val_auc: 0.9988 - val_precision: 0.9954 - val_recall: 0.9900
# Epoch 14/20
# 1100000/1100000 [==============================] - 42s 38us/sample - loss: 0.0086 - auc: 0.9998 - precision: 0.9996 - recall: 0.9683 - val_loss: 0.0197 - val_auc: 0.9988 - val_precision: 0.9958 - val_recall: 0.9900
# Epoch 15/20
# 1100000/1100000 [==============================] - 49s 45us/sample - loss: 0.0085 - auc: 0.9998 - precision: 0.9996 - recall: 0.9684 - val_loss: 0.0213 - val_auc: 0.9988 - val_precision: 0.9958 - val_recall: 0.9900
# Epoch 16/20
# 1100000/1100000 [==============================] - 47s 42us/sample - loss: 0.0085 - auc: 0.9998 - precision: 0.9996 - recall: 0.9684 - val_loss: 0.0218 - val_auc: 0.9988 - val_precision: 0.9956 - val_recall: 0.9900
# Epoch 17/20
# 1100000/1100000 [==============================] - 48s 44us/sample - loss: 0.0085 - auc: 0.9998 - precision: 0.9996 - recall: 0.9684 - val_loss: 0.0211 - val_auc: 0.9988 - val_precision: 0.9958 - val_recall: 0.9900
# Epoch 18/20
# 1100000/1100000 [==============================] - 51s 46us/sample - loss: 0.0085 - auc: 0.9998 - precision: 0.9996 - recall: 0.9684 - val_loss: 0.0223 - val_auc: 0.9988 - val_precision: 0.9958 - val_recall: 0.9900
# Epoch 19/20
# 1100000/1100000 [==============================] - 50s 45us/sample - loss: 0.0085 - auc: 0.9998 - precision: 0.9996 - recall: 0.9684 - val_loss: 0.0218 - val_auc: 0.9988 - val_precision: 0.9958 - val_recall: 0.9900
# Epoch 20/20
# 1100000/1100000 [==============================] - 49s 44us/sample - loss: 0.0085 - auc: 0.9998 - precision: 0.9996 - recall: 0.9684 - val_loss: 0.0219 - val_auc: 0.9988 - val_precision: 0.9958 - val_recall: 0.9900

# %% [markdown]
# [Output omitted for brevity]

# %% [markdown]
# ### Validation
#
# Inspecting the metrics and learning curves, we observe that the model does not significantly overfit the training set.

# %%
model_class_weights = models.load_model('models/model_class_weight.h5')
evaluate_model(model_class_weights, 
               X_train, 
               y_train_is_attack, 
               X_val, 
               y_val.label_is_attack.values,
               metric_title='Loss / PR AUC / Precision / Recall')
# Out:
# Evaluation:
# ===========
#        Loss / PR AUC / Precision / Recall
# 2022-07-09 16:06:34.799446: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 598400000 exceeds 10% of system memory.
# Train: [0.06550089137337424, 0.9997967, 0.99959713, 0.967652]
# Val:   [0.035699211061000824, 0.99908024, 0.9957552, 0.9891075]

# %%
fix, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(20, 8))

plot_hist(hist, ax=ax1)
plot_hist(hist, metrics=['auc', 'val_auc'], ax=ax2)
plot_hist(hist, metrics=['precision', 'val_precision'], ax=ax3)
plot_hist(hist, metrics=['recall', 'val_recall'], ax=ax4)

# %% [markdown]
# ### Performance
#
# The performance of the model in terms of the PR score is only marginally better than the previous model with a score of `0.97735`.
# However, the classification report shows a different combination of precision and recall for the positive class, with a precision of `0.965` and recall of `0.954`.
# The confusion matrix reveals a nearly equal amount of false-positives (`9375` samples) and false-negatives (`12649` samples).
# Even though the misclassification rate of `Infiltration` was reduced to `77%`, it still is very high.

# %%
pred_val_score = predict_proba(model_class_weights, X_val)
plot_pr_curve(y_val.label_is_attack.values, pred_val_score)
# Out:
# Average PR Score 0.9992511758631766

# %%
pred_val = predict(model_class_weights, X_val)
print_binary_performance(y_val, y_val.label_is_attack, pred_val)
# Out:
# Classification Report:
# ======================
#               precision    recall  f1-score   support
#
#            0      0.986     0.994     0.990      4308
#            1      0.996     0.989     0.992      5692
#
#     accuracy                          0.991     10000
#    macro avg      0.991     0.992     0.991     10000
# weighted avg      0.991     0.991     0.991     10000
#
# Confusion Matrix:
# =================
# Misclassifications by attack category:
# ======================================
#                        misclassified  total  percent_misclassified
# Brute Force -Web                  13     61               0.213115
# Bot                               44    852               0.051643
# Benign                            24   4308               0.005571
# DoS attacks-GoldenEye              5    993               0.005035

# %% [markdown]
# ### 3.3 Model Comparison
#
# |Model|PR Score|Precision Positive|Recall Positive|False-Positives|False-Negatives|
# |---|---|---|---|---|---|
# |No class-weights|0.97718|0.992|**0.939**|1956|**16898**|
# |Class-weights|0.97735|0.965|**0.954**|9375|**12649**|
#
# Using the class weights during training, we obtain a reduction in precision of `~2.7%` but an increase in recall of `~1.6%`.
# Consequently, the number of false-negatives are reduced, while the number of false-positives are increased by an acceptable amount.
# As the primary goal of our classifier is to detect as many attacks as possible, we choose to continue using the second approach, applying the class weights during training.
#
# Both models suffer from a high misclassification rate in regards to the attack category of `Infiltration`, most likely due to the fact that benign traffic and infiltration traffic is very similar.

# %% [markdown]
# ## 4. Model Training with Hyperparameter Optimization
#
# In this section we will use the [Hyperopt](https://github.com/hyperopt/hyperopt) library to train and evaluate various model architectures in combination with different hyperparameter configurations. For this purpose, we define a training method that accepts the model parameters from the Hyperopt library, dynamically creating the model, performing training and returning the lowest validation loss.

# %%
def train_dynamic_model(args):
    print('\nRun') 
    print('==========')
    print('Parameters:\n{}'.format(args))
    
    epochs = int(args['epochs'])
    batch_size = int(args['batch_size'])
    nr_layers = int(args['nr_layers'])
    nr_units = int(args['nr_units'])
    activation = args['activation']
    dropout_rate = args['dropout_rate']
    model_name = 'models/{}.h5'.format(uuid.uuid4())
    
    if activation == 'elu':
        kerner_initializer = 'he_normal'
        dropout_layer = layers.Dropout(dropout_rate)
    elif activation == 'selu':
        kerner_initializer = 'lecun_normal'
        dropout_layer = layers.AlphaDropout(dropout_rate)
    else:
        raise ValueError('Invalid activation "{}" supplied.'.format(opt_args['name']))
    
    opt_name = args['optimizer']['name']
    opt_lr_mult = args['optimizer']['lr_mult']
    
    if opt_name == 'sgd':
        optimizer = optimizers.SGD(lr=(0.01 * opt_lr_mult), momentum=0.9, nesterov=True)
    elif opt_name == 'adam':
        optimizer = optimizers.Adam(lr=(0.001 * opt_lr_mult))
    elif opt_name == 'nadam':
        optimizer = optimizers.Nadam(lr=(0.002 * opt_lr_mult))
    else:
        raise ValueError('Invalid optimizer "{}" supplied.'.format(opt_args['name']))
        
    K.clear_session()
    gc.collect()
    
    model = create_model(input_dims=X_train.shape[1], 
                         nr_layers=nr_layers, 
                         nr_units=nr_units, 
                         activation=activation, 
                         kerner_initializer=kerner_initializer,
                         optimizer=optimizer,
                         dropout_layer=dropout_layer)
    
    mc = callbacks.ModelCheckpoint(filepath=model_name, save_best_only=True, verbose=0)
    
    lr_scheduler = callbacks.ReduceLROnPlateau(factor=0.2, patience=5)
    
    hist = model.fit(x=X_train, 
                     y=y_train_is_attack, 
                     validation_data=(X_val, y_val.label_is_attack.values),
                     batch_size=batch_size,
                     epochs=epochs,
                     class_weight=class_weights,
                     callbacks=[
                         lr_scheduler,
                         mc
                     ],
                     verbose=2)
    
    best_loss = np.amin(hist.history['val_loss']) 
    print('Best loss: {}'.format(best_loss))
    print('Model: {}'.format(model_name))
    
    return {
        'loss': best_loss,
        'status': STATUS_OK,
        'model_name': model_name
    }

# %% [markdown]
# ### 4.1 Search-Space Definition and Training
#
# In order to try a variety of different model architectures and hyperparameters, we have to define the search spaces for each of our parameters. These search spaces will be used to choose values for the corresponding parameters.
# The following search spaces are utilized:
# * Number of layers: uniform integer space in the interval of `[2, 6]`.
# * Number of units: uniform integer space in the interval of `[100, 1000]` with step size `100`.
# * Activation function: choice of `elu` and `selu` activation functions.
# * Dropout rate: uniform space in the interval of `[0, 0.5]`.
# * Optimizer: choice of `SGD`, `Adam` or `Nadam`.
# * Learning rate multiplier: log-uniform space in the interval of `[-0.5, 1]`. This value is used to multiply the default learning rate of the chosen optimizer.
#
# Training is performed on `50` models, with `30` epochs per model and a rather large batch-size of `4096`, which is chosen to keep the training time per model reasonable.
#
# We use the [Tree of Parzen Estimators (TPE)](https://papers.nips.cc/paper/4443-algorithms-for-hyper-parameter-optimization.pdf) search algorithm, provided by Hyperopt, to optimize the search process.

# %%
trials = Trials()

space = { 
    'epochs': hp.choice('epochs', [30]),  
    'batch_size': hp.choice('batch_size', [4096]),
    'nr_layers': hp.quniform('nr_layers', 2, 6, 1),  
    'nr_units': hp.quniform('nr_units', 100, 1000, 100), 
    'activation': hp.choice('activation', ['elu', 'selu']),
    'dropout_rate': hp.uniform('dropout_rate', 0, 0.5),
    'optimizer': hp.choice('optimizer', [
        {
            'name': 'sgd',
            'lr_mult': hp.loguniform('sgd_lr_rate_mult', -0.5, 1),
        }, 
        {
            'name': 'adam',
            'lr_mult': hp.loguniform('adam_lr_rate_mult', -0.5, 1),
        },
        {
            'name': 'nadam',
            'lr_mult': hp.loguniform('nadam_lr_rate_mult', -0.5, 1),
        }
    ])
}


best_run = fmin(fn=train_dynamic_model,
                space=space,
                algo=tpe.suggest,
                max_evals=50,
                trials=trials)
# Out:
#
# Run
# ==========
# Parameters:
# {'activation': 'selu', 'batch_size': 4096, 'dropout_rate': 0.07492742950305509, 'epochs': 30, 'nr_layers': 4.0, 'nr_units': 900.0, 'optimizer': {'lr_mult': 1.8293606025633262, 'name': 'sgd'}}
# Train on 1100000 samples, validate on 10000 samples
# Epoch 1/30
#   0%|          | 0/50 [00:06<?, ?it/s, best loss: ?]
# 2022-07-09 16:07:20.396983: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 598400000 exceeds 10% of system memory.
# 1100000/1100000 - 209s - loss: 0.0354 - auc: 0.9974 - precision: 0.9892 - recall: 0.9176 - val_loss: 0.0495 - val_auc: 0.9964 - val_precision: 0.9855 - val_recall: 0.9188
#
# Epoch 2/30
# 1100000/1100000 - 219s - loss: 0.0243 - auc: 0.9988 - precision: 0.9941 - recall: 0.9416 - val_loss: 0.0532 - val_auc: 0.9953 - val_precision: 0.9858 - val_recall: 0.9893
#
# Epoch 3/30
# 1100000/1100000 - 210s - loss: 0.0203 - auc: 0.9990 - precision: 0.9960 - recall: 0.9541 - val_loss: 0.0457 - val_auc: 0.9937 - val_precision: 0.9903 - val_recall: 0.9879
#
# Epoch 4/30
# 1100000/1100000 - 206s - loss: 0.0164 - auc: 0.9991 - precision: 0.9978 - recall: 0.9633 - val_loss: 0.0374 - val_auc: 0.9944 - val_precision: 0.9908 - val_recall: 0.9877
#
# Epoch 5/30
# 1100000/1100000 - 210s - loss: 0.0148 - auc: 0.9992 - precision: 0.9983 - recall: 0.9649 - val_loss: 0.0422 - val_auc: 0.9939 - val_precision: 0.9909 - val_recall: 0.9898
#
# Epoch 6/30
# 1100000/1100000 - 209s - loss: 0.0144 - auc: 0.9992 - precision: 0.9983 - recall: 0.9654 - val_loss: 0.0442 - val_auc: 0.9941 - val_precision: 0.9907 - val_recall: 0.9898
#
# Epoch 7/30
# 1100000/1100000 - 206s - loss: 0.0133 - auc: 0.9994 - precision: 0.9985 - recall: 0.9664 - val_loss: 0.0344 - val_auc: 0.9949 - val_precision: 0.9910 - val_recall: 0.9898
#
# Epoch 8/30
# 1100000/1100000 - 206s - loss: 0.0129 - auc: 0.9994 - precision: 0.9985 - recall: 0.9665 - val_loss: 0.0387 - val_auc: 0.9945 - val_precision: 0.9910 - val_recall: 0.9896
#
# Epoch 9/30
# 1100000/1100000 - 204s - loss: 0.0136 - auc: 0.9994 - precision: 0.9984 - recall: 0.9655 - val_loss: 0.0408 - val_auc: 0.9949 - val_precision: 0.9907 - val_recall: 0.9888
#
# Epoch 10/30
# 1100000/1100000 - 210s - loss: 0.0125 - auc: 0.9996 - precision: 0.9987 - recall: 0.9668 - val_loss: 0.0333 - val_auc: 0.9978 - val_precision: 0.9914 - val_recall: 0.9888
#
# Epoch 11/30
# 1100000/1100000 - 206s - loss: 0.0119 - auc: 0.9996 - precision: 0.9988 - recall: 0.9673 - val_loss: 0.0259 - val_auc: 0.9982 - val_precision: 0.9919 - val_recall: 0.9889
#
# Epoch 12/30
# 1100000/1100000 - 204s - loss: 0.0115 - auc: 0.9997 - precision: 0.9988 - recall: 0.9675 - val_loss: 0.0307 - val_auc: 0.9986 - val_precision: 0.9916 - val_recall: 0.9900
#
# Epoch 13/30
# 1100000/1100000 - 207s - loss: 0.0119 - auc: 0.9996 - precision: 0.9987 - recall: 0.9668 - val_loss: 0.0316 - val_auc: 0.9984 - val_precision: 0.9914 - val_recall: 0.9900
#
# Epoch 14/30
# 1100000/1100000 - 208s - loss: 0.0109 - auc: 0.9997 - precision: 0.9989 - recall: 0.9677 - val_loss: 0.0235 - val_auc: 0.9986 - val_precision: 0.9923 - val_recall: 0.9900
#
# Epoch 15/30
# 1100000/1100000 - 201s - loss: 0.0127 - auc: 0.9995 - precision: 0.9987 - recall: 0.9660 - val_loss: 0.0271 - val_auc: 0.9987 - val_precision: 0.9921 - val_recall: 0.9884
#
# Epoch 16/30
# 1100000/1100000 - 204s - loss: 0.0106 - auc: 0.9997 - precision: 0.9990 - recall: 0.9677 - val_loss: 0.0206 - val_auc: 0.9985 - val_precision: 0.9917 - val_recall: 0.9900
#
# Epoch 17/30
# 1100000/1100000 - 191s - loss: 0.0103 - auc: 0.9997 - precision: 0.9991 - recall: 0.9681 - val_loss: 0.0279 - val_auc: 0.9982 - val_precision: 0.9921 - val_recall: 0.9900
#
# Epoch 18/30
# 1100000/1100000 - 188s - loss: 0.0102 - auc: 0.9997 - precision: 0.9991 - recall: 0.9681 - val_loss: 0.0209 - val_auc: 0.9986 - val_precision: 0.9930 - val_recall: 0.9900
#
# Epoch 19/30
# 1100000/1100000 - 187s - loss: 0.0110 - auc: 0.9996 - precision: 0.9991 - recall: 0.9675 - val_loss: 0.0227 - val_auc: 0.9985 - val_precision: 0.9944 - val_recall: 0.9900
#
# Epoch 20/30
# 1100000/1100000 - 187s - loss: 0.0099 - auc: 0.9997 - precision: 0.9993 - recall: 0.9681 - val_loss: 0.0264 - val_auc: 0.9982 - val_precision: 0.9940 - val_recall: 0.9900
#
# Epoch 21/30
# 1100000/1100000 - 187s - loss: 0.0098 - auc: 0.9997 - precision: 0.9993 - recall: 0.9684 - val_loss: 0.0326 - val_auc: 0.9983 - val_precision: 0.9945 - val_recall: 0.9900
#
# Epoch 22/30
# 1100000/1100000 - 187s - loss: 0.0094 - auc: 0.9998 - precision: 0.9994 - recall: 0.9684 - val_loss: 0.0203 - val_auc: 0.9983 - val_precision: 0.9949 - val_recall: 0.9900
#
# Epoch 23/30
# 1100000/1100000 - 187s - loss: 0.0094 - auc: 0.9998 - precision: 0.9994 - recall: 0.9682 - val_loss: 0.0176 - val_auc: 0.9984 - val_precision: 0.9954 - val_recall: 0.9900
#
# Epoch 24/30
# 1100000/1100000 - 188s - loss: 0.0094 - auc: 0.9997 - precision: 0.9995 - recall: 0.9683 - val_loss: 0.0173 - val_auc: 0.9986 - val_precision: 0.9958 - val_recall: 0.9900
#
# Epoch 25/30
# 1100000/1100000 - 205s - loss: 0.0093 - auc: 0.9998 - precision: 0.9995 - recall: 0.9682 - val_loss: 0.0214 - val_auc: 0.9983 - val_precision: 0.9954 - val_recall: 0.9900
#
# Epoch 26/30
# 1100000/1100000 - 201s - loss: 0.0093 - auc: 0.9998 - precision: 0.9994 - recall: 0.9683 - val_loss: 0.0190 - val_auc: 0.9986 - val_precision: 0.9961 - val_recall: 0.9900
#
# Epoch 27/30
# 1100000/1100000 - 203s - loss: 0.0093 - auc: 0.9998 - precision: 0.9995 - recall: 0.9682 - val_loss: 0.0228 - val_auc: 0.9984 - val_precision: 0.9958 - val_recall: 0.9900
#
# Epoch 28/30
# 1100000/1100000 - 210s - loss: 0.0093 - auc: 0.9998 - precision: 0.9995 - recall: 0.9683 - val_loss: 0.0179 - val_auc: 0.9986 - val_precision: 0.9959 - val_recall: 0.9900
#
# Epoch 29/30
# 1100000/1100000 - 192s - loss: 0.0093 - auc: 0.9998 - precision: 0.9995 - recall: 0.9683 - val_loss: 0.0171 - val_auc: 0.9984 - val_precision: 0.9958 - val_recall: 0.9900
#
# Epoch 30/30
# 1100000/1100000 - 208s - loss: 0.0092 - auc: 0.9998 - precision: 0.9995 - recall: 0.9683 - val_loss: 0.0176 - val_auc: 0.9986 - val_precision: 0.9959 - val_recall: 0.9900
#
# Best loss: 0.017109515661001204
# Model: models/93e8260c-7c61-491f-b076-ce125a17eaf7.h5
#
# Run
# ==========
# Parameters:
# {'activation': 'elu', 'batch_size': 4096, 'dropout_rate': 0.3095169963722218, 'epochs': 30, 'nr_layers': 3.0, 'nr_units': 600.0, 'optimizer': {'lr_mult': 0.8779693185271832, 'name': 'sgd'}}
# Train on 1100000 samples, validate on 10000 samples
# Epoch 1/30
# 1100000/1100000 - 65s - loss: 0.0494 - auc: 0.9948 - precision: 0.9837 - recall: 0.8937 - val_loss: 0.0889 - val_auc: 0.9955 - val_precision: 0.9013 - val_recall: 0.9946
#
# Epoch 2/30
# 1100000/1100000 - 67s - loss: 0.0364 - auc: 0.9973 - precision: 0.9879 - recall: 0.9208 - val_loss: 0.0800 - val_auc: 0.9959 - val_precision: 0.9244 - val_recall: 0.9947
#
# Epoch 3/30
# 1100000/1100000 - 69s - loss: 0.0325 - auc: 0.9979 - precision: 0.9896 - recall: 0.9318 - val_loss: 0.0726 - val_auc: 0.9964 - val_precision: 0.9695 - val_recall: 0.9868
#
# Epoch 4/30
# 1100000/1100000 - 64s - loss: 0.0302 - auc: 0.9983 - precision: 0.9911 - recall: 0.9409 - val_loss: 0.0702 - val_auc: 0.9966 - val_precision: 0.9769 - val_recall: 0.9870
#
# Epoch 5/30
# 1100000/1100000 - 60s - loss: 0.0282 - auc: 0.9986 - precision: 0.9925 - recall: 0.9497 - val_loss: 0.0691 - val_auc: 0.9968 - val_precision: 0.9776 - val_recall: 0.9889
#
# Epoch 6/30
# 1100000/1100000 - 59s - loss: 0.0267 - auc: 0.9988 - precision: 0.9935 - recall: 0.9552 - val_loss: 0.0705 - val_auc: 0.9966 - val_precision: 0.9555 - val_recall: 0.9891
#
# Epoch 7/30
# 1100000/1100000 - 59s - loss: 0.0254 - auc: 0.9989 - precision: 0.9944 - recall: 0.9599 - val_loss: 0.0598 - val_auc: 0.9965 - val_precision: 0.9812 - val_recall: 0.9889
#
# Epoch 8/30
# 1100000/1100000 - 62s - loss: 0.0242 - auc: 0.9990 - precision: 0.9953 - recall: 0.9620 - val_loss: 0.0595 - val_auc: 0.9967 - val_precision: 0.9812 - val_recall: 0.9889
#
# Epoch 9/30
# 1100000/1100000 - 62s - loss: 0.0232 - auc: 0.9990 - precision: 0.9960 - recall: 0.9632 - val_loss: 0.0617 - val_auc: 0.9956 - val_precision: 0.9837 - val_recall: 0.9889
#
# Epoch 10/30
# 1100000/1100000 - 58s - loss: 0.0223 - auc: 0.9990 - precision: 0.9967 - recall: 0.9636 - val_loss: 0.0590 - val_auc: 0.9954 - val_precision: 0.9819 - val_recall: 0.9891
#
# Epoch 11/30
# 1100000/1100000 - 58s - loss: 0.0214 - auc: 0.9990 - precision: 0.9972 - recall: 0.9637 - val_loss: 0.0566 - val_auc: 0.9946 - val_precision: 0.9861 - val_recall: 0.9881
#
# Epoch 12/30
# 1100000/1100000 - 60s - loss: 0.0206 - auc: 0.9991 - precision: 0.9976 - recall: 0.9633 - val_loss: 0.0561 - val_auc: 0.9945 - val_precision: 0.9853 - val_recall: 0.9879
#
# Epoch 13/30
# 1100000/1100000 - 58s - loss: 0.0199 - auc: 0.9991 - precision: 0.9978 - recall: 0.9634 - val_loss: 0.0496 - val_auc: 0.9949 - val_precision: 0.9832 - val_recall: 0.9877
#
# Epoch 14/30
# 1100000/1100000 - 60s - loss: 0.0193 - auc: 0.9991 - precision: 0.9979 - recall: 0.9635 - val_loss: 0.0507 - val_auc: 0.9947 - val_precision: 0.9891 - val_recall: 0.9877
#
# Epoch 15/30
# 1100000/1100000 - 58s - loss: 0.0187 - auc: 0.9991 - precision: 0.9980 - recall: 0.9633 - val_loss: 0.0520 - val_auc: 0.9946 - val_precision: 0.9867 - val_recall: 0.9877
#
# Epoch 16/30
# 1100000/1100000 - 59s - loss: 0.0182 - auc: 0.9991 - precision: 0.9981 - recall: 0.9634 - val_loss: 0.0473 - val_auc: 0.9945 - val_precision: 0.9893 - val_recall: 0.9874
#
# Epoch 17/30
# 1100000/1100000 - 62s - loss: 0.0178 - auc: 0.9991 - precision: 0.9982 - recall: 0.9634 - val_loss: 0.0497 - val_auc: 0.9935 - val_precision: 0.9905 - val_recall: 0.9875
#
# Epoch 18/30
# 1100000/1100000 - 58s - loss: 0.0174 - auc: 0.9991 - precision: 0.9982 - recall: 0.9635 - val_loss: 0.0471 - val_auc: 0.9937 - val_precision: 0.9896 - val_recall: 0.9875
#
# Epoch 19/30
# 1100000/1100000 - 61s - loss: 0.0171 - auc: 0.9991 - precision: 0.9982 - recall: 0.9637 - val_loss: 0.0493 - val_auc: 0.9934 - val_precision: 0.9905 - val_recall: 0.9877
#
# Epoch 20/30
# 1100000/1100000 - 57s - loss: 0.0167 - auc: 0.9991 - precision: 0.9983 - recall: 0.9636 - val_loss: 0.0531 - val_auc: 0.9935 - val_precision: 0.9880 - val_recall: 0.9877
#
# Epoch 21/30
# 1100000/1100000 - 65s - loss: 0.0164 - auc: 0.9991 - precision: 0.9984 - recall: 0.9639 - val_loss: 0.0548 - val_auc: 0.9936 - val_precision: 0.9884 - val_recall: 0.9879
#
# Epoch 22/30
# 1100000/1100000 - 69s - loss: 0.0162 - auc: 0.9991 - precision: 0.9984 - recall: 0.9640 - val_loss: 0.0465 - val_auc: 0.9937 - val_precision: 0.9901 - val_recall: 0.9884
#
# Epoch 23/30
# 1100000/1100000 - 70s - loss: 0.0160 - auc: 0.9991 - precision: 0.9984 - recall: 0.9640 - val_loss: 0.0464 - val_auc: 0.9936 - val_precision: 0.9908 - val_recall: 0.9882
#
# Epoch 24/30
# 1100000/1100000 - 67s - loss: 0.0158 - auc: 0.9991 - precision: 0.9985 - recall: 0.9642 - val_loss: 0.0489 - val_auc: 0.9937 - val_precision: 0.9915 - val_recall: 0.9888
#
# Epoch 25/30
# 1100000/1100000 - 81s - loss: 0.0156 - auc: 0.9991 - precision: 0.9985 - recall: 0.9643 - val_loss: 0.0475 - val_auc: 0.9935 - val_precision: 0.9905 - val_recall: 0.9888
#
# Epoch 26/30
# 1100000/1100000 - 68s - loss: 0.0155 - auc: 0.9991 - precision: 0.9985 - recall: 0.9645 - val_loss: 0.0453 - val_auc: 0.9936 - val_precision: 0.9915 - val_recall: 0.9884
#
# Epoch 27/30
# 1100000/1100000 - 66s - loss: 0.0153 - auc: 0.9991 - precision: 0.9985 - recall: 0.9645 - val_loss: 0.0506 - val_auc: 0.9935 - val_precision: 0.9910 - val_recall: 0.9888
#
# Epoch 28/30
# 1100000/1100000 - 69s - loss: 0.0152 - auc: 0.9991 - precision: 0.9985 - recall: 0.9646 - val_loss: 0.0430 - val_auc: 0.9936 - val_precision: 0.9914 - val_recall: 0.9884
#
# Epoch 29/30
# 1100000/1100000 - 68s - loss: 0.0151 - auc: 0.9991 - precision: 0.9986 - recall: 0.9646 - val_loss: 0.0450 - val_auc: 0.9936 - val_precision: 0.9912 - val_recall: 0.9888
#
# Epoch 30/30
# 1100000/1100000 - 63s - loss: 0.0150 - auc: 0.9991 - precision: 0.9986 - recall: 0.9647 - val_loss: 0.0439 - val_auc: 0.9936 - val_precision: 0.9914 - val_recall: 0.9884
#
# Best loss: 0.04298626558184624
# Model: models/5c894b0a-0431-4b3f-96e4-3a6a0bdfe6bb.h5
#
# Run
# ==========
# Parameters:
# {'activation': 'selu', 'batch_size': 4096, 'dropout_rate': 0.4046965698783848, 'epochs': 30, 'nr_layers': 4.0, 'nr_units': 300.0, 'optimizer': {'lr_mult': 1.6153755614876235, 'name': 'sgd'}}
# Train on 1100000 samples, validate on 10000 samples
# Epoch 1/30
# 1100000/1100000 - 56s - loss: 0.0542 - auc: 0.9936 - precision: 0.9826 - recall: 0.8750 - val_loss: 0.1023 - val_auc: 0.9948 - val_precision: 0.9062 - val_recall: 0.9946
#
# Epoch 2/30
# 1100000/1100000 - 51s - loss: 0.0368 - auc: 0.9972 - precision: 0.9887 - recall: 0.9119 - val_loss: 0.0746 - val_auc: 0.9954 - val_precision: 0.9769 - val_recall: 0.9884
#
# Epoch 3/30
# 1100000/1100000 - 48s - loss: 0.0312 - auc: 0.9980 - precision: 0.9909 - recall: 0.9260 - val_loss: 0.0652 - val_auc: 0.9945 - val_precision: 0.9762 - val_recall: 0.9874
#
# Epoch 4/30
# 1100000/1100000 - 51s - loss: 0.0266 - auc: 0.9986 - precision: 0.9933 - recall: 0.9408 - val_loss: 0.0509 - val_auc: 0.9941 - val_precision: 0.9815 - val_recall: 0.9875
#
# Epoch 5/30
# 1100000/1100000 - 49s - loss: 0.0226 - auc: 0.9990 - precision: 0.9954 - recall: 0.9518 - val_loss: 0.0584 - val_auc: 0.9932 - val_precision: 0.9836 - val_recall: 0.9895
#
# Epoch 6/30
# 1100000/1100000 - 46s - loss: 0.0193 - auc: 0.9991 - precision: 0.9967 - recall: 0.9588 - val_loss: 0.0544 - val_auc: 0.9925 - val_precision: 0.9848 - val_recall: 0.9895
#
# Epoch 7/30
# 1100000/1100000 - 49s - loss: 0.0172 - auc: 0.9992 - precision: 0.9977 - recall: 0.9621 - val_loss: 0.0470 - val_auc: 0.9932 - val_precision: 0.9903 - val_recall: 0.9893
#
# Epoch 8/30
# 1100000/1100000 - 47s - loss: 0.0159 - auc: 0.9992 - precision: 0.9981 - recall: 0.9632 - val_loss: 0.0496 - val_auc: 0.9928 - val_precision: 0.9910 - val_recall: 0.9893
#
# Epoch 9/30
# 1100000/1100000 - 46s - loss: 0.0152 - auc: 0.9992 - precision: 0.9984 - recall: 0.9638 - val_loss: 0.0528 - val_auc: 0.9928 - val_precision: 0.9881 - val_recall: 0.9896
#
# Epoch 10/30
# 1100000/1100000 - 46s - loss: 0.0146 - auc: 0.9992 - precision: 0.9985 - recall: 0.9639 - val_loss: 0.0512 - val_auc: 0.9907 - val_precision: 0.9879 - val_recall: 0.9888
#
# Epoch 11/30
# 1100000/1100000 - 42s - loss: 0.0143 - auc: 0.9992 - precision: 0.9987 - recall: 0.9643 - val_loss: 0.0488 - val_auc: 0.9915 - val_precision: 0.9884 - val_recall: 0.9881
#
# Epoch 12/30
# 1100000/1100000 - 38s - loss: 0.0140 - auc: 0.9993 - precision: 0.9987 - recall: 0.9644 - val_loss: 0.0464 - val_auc: 0.9920 - val_precision: 0.9915 - val_recall: 0.9888
#
# Epoch 13/30
# 1100000/1100000 - 40s - loss: 0.0137 - auc: 0.9993 - precision: 0.9988 - recall: 0.9647 - val_loss: 0.0499 - val_auc: 0.9910 - val_precision: 0.9881 - val_recall: 0.9896
#
# Epoch 14/30
# 1100000/1100000 - 40s - loss: 0.0135 - auc: 0.9993 - precision: 0.9988 - recall: 0.9648 - val_loss: 0.0460 - val_auc: 0.9917 - val_precision: 0.9917 - val_recall: 0.9896
#
# Epoch 15/30
# 1100000/1100000 - 43s - loss: 0.0132 - auc: 0.9993 - precision: 0.9989 - recall: 0.9651 - val_loss: 0.0475 - val_auc: 0.9917 - val_precision: 0.9881 - val_recall: 0.9896
#
# Epoch 16/30
# 1100000/1100000 - 44s - loss: 0.0131 - auc: 0.9993 - precision: 0.9989 - recall: 0.9651 - val_loss: 0.0465 - val_auc: 0.9925 - val_precision: 0.9912 - val_recall: 0.9896
#
# Epoch 17/30
# 1100000/1100000 - 40s - loss: 0.0129 - auc: 0.9994 - precision: 0.9989 - recall: 0.9655 - val_loss: 0.0472 - val_auc: 0.9927 - val_precision: 0.9909 - val_recall: 0.9896
#
# Epoch 18/30
# 1100000/1100000 - 43s - loss: 0.0128 - auc: 0.9994 - precision: 0.9989 - recall: 0.9654 - val_loss: 0.0476 - val_auc: 0.9929 - val_precision: 0.9910 - val_recall: 0.9896
#
# Epoch 19/30
# 1100000/1100000 - 40s - loss: 0.0126 - auc: 0.9994 - precision: 0.9990 - recall: 0.9656 - val_loss: 0.0427 - val_auc: 0.9921 - val_precision: 0.9917 - val_recall: 0.9889
#
# Epoch 20/30
# 1100000/1100000 - 41s - loss: 0.0125 - auc: 0.9994 - precision: 0.9990 - recall: 0.9657 - val_loss: 0.0413 - val_auc: 0.9936 - val_precision: 0.9917 - val_recall: 0.9896
#
# Epoch 21/30
# 1100000/1100000 - 39s - loss: 0.0123 - auc: 0.9995 - precision: 0.9990 - recall: 0.9660 - val_loss: 0.0437 - val_auc: 0.9936 - val_precision: 0.9919 - val_recall: 0.9898
#
# Epoch 22/30
# 1100000/1100000 - 40s - loss: 0.0122 - auc: 0.9995 - precision: 0.9990 - recall: 0.9662 - val_loss: 0.0396 - val_auc: 0.9921 - val_precision: 0.9922 - val_recall: 0.9888
#
# Epoch 23/30
# 1100000/1100000 - 39s - loss: 0.0121 - auc: 0.9995 - precision: 0.9990 - recall: 0.9662 - val_loss: 0.0396 - val_auc: 0.9921 - val_precision: 0.9916 - val_recall: 0.9896
#
# Epoch 24/30
# 1100000/1100000 - 39s - loss: 0.0120 - auc: 0.9995 - precision: 0.9990 - recall: 0.9664 - val_loss: 0.0393 - val_auc: 0.9935 - val_precision: 0.9917 - val_recall: 0.9900
#
# Epoch 25/30
# 1100000/1100000 - 38s - loss: 0.0119 - auc: 0.9995 - precision: 0.9991 - recall: 0.9665 - val_loss: 0.0414 - val_auc: 0.9931 - val_precision: 0.9919 - val_recall: 0.9900
#
# Epoch 26/30
# 1100000/1100000 - 47s - loss: 0.0118 - auc: 0.9996 - precision: 0.9991 - recall: 0.9666 - val_loss: 0.0380 - val_auc: 0.9923 - val_precision: 0.9926 - val_recall: 0.9891
#
# Epoch 27/30
# 1100000/1100000 - 46s - loss: 0.0116 - auc: 0.9996 - precision: 0.9991 - recall: 0.9667 - val_loss: 0.0429 - val_auc: 0.9933 - val_precision: 0.9919 - val_recall: 0.9900
#
# Epoch 28/30
# 1100000/1100000 - 42s - loss: 0.0116 - auc: 0.9996 - precision: 0.9991 - recall: 0.9669 - val_loss: 0.0340 - val_auc: 0.9928 - val_precision: 0.9924 - val_recall: 0.9889
#
# Epoch 29/30
# 1100000/1100000 - 43s - loss: 0.0115 - auc: 0.9996 - precision: 0.9991 - recall: 0.9668 - val_loss: 0.0374 - val_auc: 0.9940 - val_precision: 0.9914 - val_recall: 0.9900
#
# Epoch 30/30
# 1100000/1100000 - 40s - loss: 0.0113 - auc: 0.9996 - precision: 0.9991 - recall: 0.9670 - val_loss: 0.0346 - val_auc: 0.9944 - val_precision: 0.9923 - val_recall: 0.9898
#
# Best loss: 0.03402770608961582
# Model: models/22888810-87db-4bc7-9d1e-74bcc8db95bb.h5
#
# Run
# ==========
# Parameters:
# {'activation': 'elu', 'batch_size': 4096, 'dropout_rate': 0.49192863625456423, 'epochs': 30, 'nr_layers': 4.0, 'nr_units': 400.0, 'optimizer': {'lr_mult': 2.2823508443220426, 'name': 'sgd'}}
# Train on 1100000 samples, validate on 10000 samples
# Epoch 1/30
# 1100000/1100000 - 46s - loss: 0.0410 - auc: 0.9965 - precision: 0.9875 - recall: 0.9149 - val_loss: 0.0678 - val_auc: 0.9962 - val_precision: 0.9803 - val_recall: 0.9875
#
# Epoch 2/30
# 1100000/1100000 - 44s - loss: 0.0263 - auc: 0.9988 - precision: 0.9937 - recall: 0.9558 - val_loss: 0.0531 - val_auc: 0.9962 - val_precision: 0.9853 - val_recall: 0.9893
#
# Epoch 3/30
# 1100000/1100000 - 44s - loss: 0.0215 - auc: 0.9990 - precision: 0.9968 - recall: 0.9636 - val_loss: 0.0491 - val_auc: 0.9945 - val_precision: 0.9901 - val_recall: 0.9886
#
# Epoch 4/30
# 1100000/1100000 - 41s - loss: 0.0187 - auc: 0.9991 - precision: 0.9978 - recall: 0.9641 - val_loss: 0.0406 - val_auc: 0.9935 - val_precision: 0.9870 - val_recall: 0.9879
#
# Epoch 5/30
# 1100000/1100000 - 47s - loss: 0.0169 - auc: 0.9991 - precision: 0.9981 - recall: 0.9643 - val_loss: 0.0481 - val_auc: 0.9936 - val_precision: 0.9851 - val_recall: 0.9889
#
# Epoch 6/30
# 1100000/1100000 - 42s - loss: 0.0160 - auc: 0.9991 - precision: 0.9982 - recall: 0.9649 - val_loss: 0.0536 - val_auc: 0.9935 - val_precision: 0.9855 - val_recall: 0.9898
#
# Epoch 7/30
# 1100000/1100000 - 42s - loss: 0.0155 - auc: 0.9991 - precision: 0.9982 - recall: 0.9652 - val_loss: 0.0411 - val_auc: 0.9940 - val_precision: 0.9908 - val_recall: 0.9888
#
# Epoch 8/30
# 1100000/1100000 - 41s - loss: 0.0150 - auc: 0.9991 - precision: 0.9983 - recall: 0.9654 - val_loss: 0.0436 - val_auc: 0.9941 - val_precision: 0.9910 - val_recall: 0.9896
#
# Epoch 9/30
# 1100000/1100000 - 44s - loss: 0.0145 - auc: 0.9992 - precision: 0.9985 - recall: 0.9657 - val_loss: 0.0431 - val_auc: 0.9942 - val_precision: 0.9877 - val_recall: 0.9900
#
# Epoch 10/30
# 1100000/1100000 - 43s - loss: 0.0140 - auc: 0.9992 - precision: 0.9987 - recall: 0.9651 - val_loss: 0.0438 - val_auc: 0.9940 - val_precision: 0.9912 - val_recall: 0.9898
#
# Epoch 11/30
# 1100000/1100000 - 45s - loss: 0.0140 - auc: 0.9992 - precision: 0.9988 - recall: 0.9650 - val_loss: 0.0433 - val_auc: 0.9939 - val_precision: 0.9910 - val_recall: 0.9900
#
# Epoch 12/30
# 1100000/1100000 - 44s - loss: 0.0139 - auc: 0.9992 - precision: 0.9988 - recall: 0.9648 - val_loss: 0.0445 - val_auc: 0.9939 - val_precision: 0.9888 - val_recall: 0.9900
#
# Epoch 13/30
# 1100000/1100000 - 46s - loss: 0.0138 - auc: 0.9992 - precision: 0.9988 - recall: 0.9651 - val_loss: 0.0411 - val_auc: 0.9938 - val_precision: 0.9912 - val_recall: 0.9900
#
# Epoch 14/30
# 1100000/1100000 - 43s - loss: 0.0137 - auc: 0.9992 - precision: 0.9989 - recall: 0.9651 - val_loss: 0.0424 - val_auc: 0.9942 - val_precision: 0.9912 - val_recall: 0.9896
#
# Epoch 15/30
# 1100000/1100000 - 44s - loss: 0.0137 - auc: 0.9992 - precision: 0.9989 - recall: 0.9650 - val_loss: 0.0439 - val_auc: 0.9940 - val_precision: 0.9912 - val_recall: 0.9900
#
# Epoch 16/30
# 1100000/1100000 - 44s - loss: 0.0136 - auc: 0.9992 - precision: 0.9989 - recall: 0.9651 - val_loss: 0.0436 - val_auc: 0.9940 - val_precision: 0.9912 - val_recall: 0.9900
#
# Epoch 17/30
# 1100000/1100000 - 42s - loss: 0.0136 - auc: 0.9992 - precision: 0.9989 - recall: 0.9652 - val_loss: 0.0425 - val_auc: 0.9940 - val_precision: 0.9912 - val_recall: 0.9900
#
# Epoch 18/30
# 1100000/1100000 - 40s - loss: 0.0136 - auc: 0.9992 - precision: 0.9989 - recall: 0.9650 - val_loss: 0.0452 - val_auc: 0.9938 - val_precision: 0.9912 - val_recall: 0.9900
#
# Epoch 19/30
# 1100000/1100000 - 40s - loss: 0.0136 - auc: 0.9992 - precision: 0.9989 - recall: 0.9651 - val_loss: 0.0435 - val_auc: 0.9941 - val_precision: 0.9912 - val_recall: 0.9900
#
# Epoch 20/30
# 1100000/1100000 - 41s - loss: 0.0136 - auc: 0.9992 - precision: 0.9989 - recall: 0.9651 - val_loss: 0.0437 - val_auc: 0.9940 - val_precision: 0.9912 - val_recall: 0.9900
#
# Epoch 21/30
# 1100000/1100000 - 41s - loss: 0.0136 - auc: 0.9992 - precision: 0.9989 - recall: 0.9652 - val_loss: 0.0430 - val_auc: 0.9940 - val_precision: 0.9910 - val_recall: 0.9900
#
# Epoch 22/30
# 1100000/1100000 - 41s - loss: 0.0136 - auc: 0.9992 - precision: 0.9989 - recall: 0.9652 - val_loss: 0.0426 - val_auc: 0.9940 - val_precision: 0.9912 - val_recall: 0.9900
#
# Epoch 23/30
# 1100000/1100000 - 41s - loss: 0.0136 - auc: 0.9992 - precision: 0.9989 - recall: 0.9652 - val_loss: 0.0440 - val_auc: 0.9940 - val_precision: 0.9912 - val_recall: 0.9900
#
# Epoch 24/30
# 1100000/1100000 - 40s - loss: 0.0136 - auc: 0.9992 - precision: 0.9989 - recall: 0.9651 - val_loss: 0.0425 - val_auc: 0.9940 - val_precision: 0.9912 - val_recall: 0.9900
#
# Epoch 25/30
# 1100000/1100000 - 49s - loss: 0.0135 - auc: 0.9992 - precision: 0.9989 - recall: 0.9651 - val_loss: 0.0435 - val_auc: 0.9941 - val_precision: 0.9912 - val_recall: 0.9900
#
# Epoch 26/30
# 1100000/1100000 - 53s - loss: 0.0136 - auc: 0.9992 - precision: 0.9989 - recall: 0.9651 - val_loss: 0.0433 - val_auc: 0.9940 - val_precision: 0.9912 - val_recall: 0.9900
#
# Epoch 27/30
# 1100000/1100000 - 52s - loss: 0.0136 - auc: 0.9992 - precision: 0.9989 - recall: 0.9652 - val_loss: 0.0428 - val_auc: 0.9942 - val_precision: 0.9912 - val_recall: 0.9900
#
# Epoch 28/30
# 1100000/1100000 - 49s - loss: 0.0136 - auc: 0.9992 - precision: 0.9989 - recall: 0.9652 - val_loss: 0.0431 - val_auc: 0.9942 - val_precision: 0.9912 - val_recall: 0.9900
#
# Epoch 29/30
#   6%|▌         | 3/50 [2:55:25<33:32:53, 2569.65s/it, best loss: 0.017109515661001204]WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_loss` which is not available. Available metrics are: loss,auc,precision,recall,lr
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#   6%|▌         | 3/50 [2:55:47<45:54:08, 3515.93s/it, best loss: 0.017109515661001204]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_219204/1533226830.py in <module>
#      29                 algo=tpe.suggest,
#      30                 max_evals=50,
# ---> 31                 trials=trials)
#
# ~/anaconda3/envs/ml-ids-notebooks/lib/python3.7/site-packages/hyperopt/fmin.py in fmin(fn, space, algo, max_evals, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar)
#     401             catch_eval_exceptions=catch_eval_exceptions,
#     402             return_argmin=return_argmin,
# --> 403             show_progressbar=show_progressbar,
#     404         )
#     405
#
# ~/anaconda3/envs/ml-ids-notebooks/lib/python3.7/site-packages/hyperopt/base.py in fmin(self, fn, space, algo, max_evals, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar)
#     649             catch_eval_exceptions=catch_eval_exceptions,
#     650             return_argmin=return_argmin,
# --> 651             show_progressbar=show_progressbar)
#     652
#     653
#
# ~/anaconda3/envs/ml-ids-notebooks/lib/python3.7/site-packages/hyperopt/fmin.py in fmin(fn, space, algo, max_evals, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar)
#     420                     show_progressbar=show_progressbar)
#     421     rval.catch_eval_exceptions = catch_eval_exceptions
# --> 422     rval.exhaust()
#     423     if return_argmin:
#     424         if len(trials.trials) == 0:
#
# ~/anaconda3/envs/ml-ids-notebooks/lib/python3.7/site-packages/hyperopt/fmin.py in exhaust(self)
#     274     def exhaust(self):
#     275         n_done = len(self.trials)
# --> 276         self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     277         self.trials.refresh()
#     278         return self
#
# ~/anaconda3/envs/ml-ids-notebooks/lib/python3.7/site-packages/hyperopt/fmin.py in run(self, N, block_until_done)
#     239                     else:
#     240                         # -- loop over trials and do the jobs directly
# --> 241                         self.serial_evaluate()
#     242
#     243                     try:
#
# ~/anaconda3/envs/ml-ids-notebooks/lib/python3.7/site-packages/hyperopt/fmin.py in serial_evaluate(self, N)
#     139                 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     140                 try:
# --> 141                     result = self.domain.evaluate(spec, ctrl)
#     142                 except Exception as e:
#     143                     logger.info('job exception: %s' % str(e))
#
# ~/anaconda3/envs/ml-ids-notebooks/lib/python3.7/site-packages/hyperopt/base.py in evaluate(self, config, ctrl, attach_attachments)
#     854                 memo=memo,
#     855                 print_node_on_error=self.rec_eval_print_node_on_error)
# --> 856             rval = self.fn(pyll_rval)
#     857
#     858         if isinstance(rval, (float, int, np.number)):
#
# /tmp/ipykernel_219204/4219932857.py in train_dynamic_model(args)
#      58                          mc
#      59                      ],
# ---> 60                      verbose=2)
#      61
#      62     best_loss = np.amin(hist.history['val_loss'])
#
# ~/anaconda3/envs/ml-ids-notebooks/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     726         max_queue_size=max_queue_size,
#     727         workers=workers,
# --> 728         use_multiprocessing=use_multiprocessing)
#     729
#     730   def evaluate(self,
#
# ~/anaconda3/envs/ml-ids-notebooks/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     322                 mode=ModeKeys.TRAIN,
#     323                 training_context=training_context,
# --> 324                 total_epochs=epochs)
#     325             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     326
#
# ~/anaconda3/envs/ml-ids-notebooks/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     121         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     122       try:
# --> 123         batch_outs = execution_function(iterator)
#     124       except (StopIteration, errors.OutOfRangeError):
#     125         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# ~/anaconda3/envs/ml-ids-notebooks/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2_utils.py in execution_function(input_fn)
#      84     # `numpy` translates Tensors to values in Eager mode.
#      85     return nest.map_structure(_non_none_constant_value,
# ---> 86                               distributed_function(input_fn))
#      87
#      88   return execution_function
#
# ~/anaconda3/envs/ml-ids-notebooks/lib/python3.7/site-packages/tensorflow_core/python/eager/def_function.py in __call__(self, *args, **kwds)
#     455
#     456     tracing_count = self._get_tracing_count()
# --> 457     result = self._call(*args, **kwds)
#     458     if tracing_count == self._get_tracing_count():
#     459       self._call_counter.called_without_tracing()
#
# ~/anaconda3/envs/ml-ids-notebooks/lib/python3.7/site-packages/tensorflow_core/python/eager/def_function.py in _call(self, *args, **kwds)
#     485       # In this case we have created variables on the first call, so we run the
#     486       # defunned version which is guaranteed to never create variables.
# --> 487       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     488     elif self._stateful_fn is not None:
#     489       # Release the lock early so that multiple threads can perform the call
#
# ~/anaconda3/envs/ml-ids-notebooks/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in __call__(self, *args, **kwargs)
#    1821     """Calls a graph function specialized to the inputs."""
#    1822     graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 1823     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    1824
#    1825   @property
#
# ~/anaconda3/envs/ml-ids-notebooks/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1139          if isinstance(t, (ops.Tensor,
#    1140                            resource_variable_ops.BaseResourceVariable))),
# -> 1141         self.captured_inputs)
#    1142
#    1143   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/anaconda3/envs/ml-ids-notebooks/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1222     if executing_eagerly:
#    1223       flat_outputs = forward_function.call(
# -> 1224           ctx, args, cancellation_manager=cancellation_manager)
#    1225     else:
#    1226       gradient_name = self._delayed_rewrite_functions.register()
#
# ~/anaconda3/envs/ml-ids-notebooks/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     509               inputs=args,
#     510               attrs=("executor_type", executor_type, "config_proto", config),
# --> 511               ctx=ctx)
#     512         else:
#     513           outputs = execute.execute_with_cancellation(
#
# ~/anaconda3/envs/ml-ids-notebooks/lib/python3.7/site-packages/tensorflow_core/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# [Output omitted for brevity]

# %% [markdown]
# ### Training Results
#
# After completion of the hyperparameter search process, we plot the chosen parameter spaces. The selected values of the ten best performing models are colorized.
# From the graphs we can infer the following optimal parameter spaces:
# * Number of layers: the optimal number of layers seems to be in the interval of `[4, 6]`.
# * Number of units: the optimal number of units per layer seems to be in the interval of `[300, 400]`.
# * Activation function: the activation function `elu` should be preferred, as it was used for all of the best ten models.
# * Dropout rate: a dropout rate `<0.3` seems to perform the best.
# * Optimizer: the `Adam` optimizer was used for all of the ten best performing models.
# * Learning rate multiplier: the learning rate multiplier seems to perform best if kept `<1.1`.

# %%
plt.figure(figsize=(20, 5))
main_plot_history(trials)

plt.figure(figsize=(20, 20))
main_plot_vars(trials, columns=3, colorize_best=10, arrange_by_loss=False)
# Out:
# avg best error: 0.017109515661001204
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_219204/21658032.py in <module>
#       3
#       4 plt.figure(figsize=(20, 20))
# ----> 5 main_plot_vars(trials, columns=3, colorize_best=10, arrange_by_loss=False)
#
# ~/anaconda3/envs/ml-ids-notebooks/lib/python3.7/site-packages/hyperopt/plotting.py in main_plot_vars(trials, do_show, fontsize, colorize_best, columns, arrange_by_loss)
#      93     asrt = np.argsort(finite_losses)
#      94     if colorize_best is not None:
# ---> 95         colorize_thresh = finite_losses[asrt[colorize_best + 1]]
#      96     else:
#      97         # -- set to lower than best (disabled)
#
# IndexError: index 11 is out of bounds for axis 0 with size 3

# %% [markdown]
# ### Best Model Parameters
#
# The best model has the following parameter configuration:
# * `5` layers,
# * `300` units per layer,
# * a dropout rate of `0.22`,
# * `elu` activation function,
# * `Adam` optimizer,
# * learning rate multiplier of `0.61` effectively reducing the default learning rate of `0.001` to `0.00061`.

# %%
print('Best validation loss: {}\n'.format(np.min(trials.losses())))
print('Best model parameters:')
print('======================')
best_run
# Out:
# Best validation loss: 0.13028952267457333
#
# Best model parameters:
# ======================
# {'activation': 0,
#  'adam_lr_rate_mult': 0.61157158868869,
#  'batch_size': 0,
#  'dropout_rate': 0.22339774943469998,
#  'epochs': 0,
#  'nr_layers': 5.0,
#  'nr_units': 300.0,
#  'optimizer': 1}

# %%
best_model_path = trials.results[np.argmin(trials.losses())]['model_name']
print('Best model path: "{}"'.format(best_model_path))
best_model = models.load_model(best_model_path)
# Out:
# Best model path: "models/c0cb0656-558f-4311-b138-9b91ab4d1fe6.h5"

# %% [markdown]
# ### Performance
#
# The optimized model has an insignificantly higher PR score of `0.97793` compared to the static model with a score of `0.97735`.

# %%
pred_val_score = predict_proba(best_model, X_val)
plot_pr_curve(y_val.label_is_attack.values, pred_val_score)
# Out:
# Average PR Score 0.9779380329781184

# %% [markdown]
# ### 4.2 Search-Space restriction and Training
#
# As a second optimization step, we use the optimal parameter values discovered in the first round of hyperparameter search, to conduct another round of hyperparameter search on a restricted search space. This allows us to further explore the optimal parameter space.
# For this round of hyperparameter optimization we use a variable batch size and conduct `20` trials.

# %%
trials = Trials()

space = { 
    'epochs': hp.choice('epochs', [30]),  
    'batch_size': hp.quniform('batch_size', 512, 4096, 10),
    'nr_layers': hp.quniform('nr_layers', 4, 6, 1),  
    'nr_units': hp.quniform('nr_units', 300, 400, 100), 
    'activation': hp.choice('activation', ['elu']),
    'dropout_rate': hp.uniform('dropout_rate', 0, 0.3),
    'optimizer': hp.choice('optimizer', [
        {
            'name': 'adam',
            'lr_mult': hp.loguniform('adam_lr_rate_mult', -0.5, 1),
        }
    ])
}


best_run = fmin(fn=train_dynamic_model,
                space=space,
                algo=tpe.suggest,
                max_evals=20,
                trials=trials)

# %% [markdown]
# [Output omitted for brevity]

# %% [markdown]
# Unfortunately, the second round of hyperparameter search did not yield a better result, as the loss of the best model is recorded with `0.1306`, compared to the loss of `0.1302` obtained from the best model of the first round.
# The difference in the losses is negligible though, suggesting that we have found a good configuration for our model.

# %%
plt.figure(figsize=(20, 5))
main_plot_history(trials)

plt.figure(figsize=(20, 20))
main_plot_vars(trials, columns=3, colorize_best=10, arrange_by_loss=False)
# Out:
# avg best error: 0.13063318593310846
# finite loss range 0.13063318593310846 0.14781879949703883 0.1318917911982782

# %% [markdown]
# ### 4.3 Training a Model with Optimal Parameters
#
# In the last step of this section, we will use the optimal parameter values and model configuration, determined during the first round of hyperparameter search. We train a model using the optimal parameters for `200` epochs, with the objective of obtaining a better performance.

# %%
def train_optimized_model(X_train, y_train, X_val, y_val, model_path, epochs, batch_size, class_weights):    
    input_dims = X_train.shape[1]

    K.clear_session()
    gc.collect()
    
    nr_layers = 5
    nr_units = 300
    dropout_rate = 0.22339774943469998
    lr = (0.001 * 0.61157158868869)

    model = create_model(input_dims=input_dims,
                         nr_layers=nr_layers,
                         nr_units=nr_units,
                         activation='elu',
                         kerner_initializer='he_normal',
                         dropout_layer=layers.Dropout(dropout_rate),
                         optimizer=optimizers.Adam(lr=lr))

    print(model.summary())
    
    mc = callbacks.ModelCheckpoint(filepath=model_path, save_best_only=True)
    
    early_stopping = callbacks.EarlyStopping(patience=50)

    lr_scheduler = callbacks.ReduceLROnPlateau(factor=0.2, patience=5)
    
    hist = model.fit(x=X_train, 
                     y=y_train,
                     validation_data=(X_val, y_val),
                     batch_size=batch_size,
                     epochs=epochs,
                     class_weight=class_weights,
                     callbacks=[mc, lr_scheduler])
    
    return model, hist

# %%
opt_model, hist = train_optimized_model(X_train, 
                                        y_train_is_attack, 
                                        X_val, 
                                        y_val.label_is_attack.values,
                                        'models/opt_model.h5',
                                        epochs=200,
                                        batch_size=4096,
                                        class_weights=class_weights)

# %% [markdown]
# [Output omitted for brevity]

# %% [markdown]
# ### Validation
#
# Inspecting the learning curves, we observe that the model does not significantly overfit the training set.

# %%
fix, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(20, 8))

plot_hist(hist, ax=ax1)
plot_hist(hist, metrics=['auc', 'val_auc'], ax=ax2)
plot_hist(hist, metrics=['precision', 'val_precision'], ax=ax3)
plot_hist(hist, metrics=['recall', 'val_recall'], ax=ax4)

# %% [markdown]
# ### Performance
#
# After training, we obtain a model with a slightly lower loss of `0.1298` and a better PR score of `0.97816` compared to the best model found during hyperparameter search, with a loss of `0.1302` and a PR score of `0.97793`.

# %%
opt_model = models.load_model('models/opt_model.h5')
pred_val_score = predict_proba(opt_model, X_val)
plot_pr_curve(y_val.label_is_attack.values, pred_val_score)
# Out:
# Average PR Score 0.9781612882599011

# %%
pred_val = predict(opt_model, X_val)
print_binary_performance(y_val, y_val.label_is_attack, pred_val)
# Out:
# Classification Report:
# ======================
#               precision    recall  f1-score   support
#
#            0      0.991     0.993     0.992   1348471
#            1      0.967     0.954     0.960    274823
#
#     accuracy                          0.987   1623294
#    macro avg      0.979     0.974     0.976   1623294
# weighted avg      0.987     0.987     0.987   1623294
#
# Confusion Matrix:
# =================
# Misclassifications by attack category:
# ======================================
#                         misclassified    total  percent_misclassified
# Infilteration                   12466    16193               0.769839
# SQL Injection                       2        9               0.222222
# Brute Force -Web                    3       61               0.049180
# Brute Force -XSS                    1       23               0.043478
# Benign                           8966  1348471               0.006649
# DoS attacks-Slowloris               6     1099               0.005460
# Bot                               104    28619               0.003634
# DDoS attacks-LOIC-HTTP             45    57619               0.000781
# SSH-Bruteforce                      2    18759               0.000107

# %% [markdown]
# ## 5. Model Comparison
#
# The model obtained during hyperparameter optimization has a higher PR score of `0.97816` compared to the static model, having a score of `0.97735`.
# Precision and recall are very similar, with values of `0.967` for precision and `0.954` for recall.
# However, both the number of false-positives and the number of false-negatives are lower for the optimized model, as illustrated in the following table:
#
# |Model|PR Score|Precision Positive|Recall Positive|False-Positives|False-Negatives|
# |---|---|---|---|---|---|
# |Static model (no class-weights)|0.97718|**0.992**|0.939|**1956**|16898|
# |Static model (class-weights)|0.97735|0.965|0.954|9375|12649|
# |Optimized model (class-weights)|**0.97816**|0.967|**0.954**|8966|**12629**|
#
# Given the superior performance of the optimized model, we choose to use the this model going forward.

# %% [markdown]
# ## 6. Conclusion
#
# In this notebook, we explored two approaches of training a deep neural network for the task of binary classification of network traffic, concluding that training should be performed taking class imbalance into account, in order to minimize the amount of false-negatives.
# Furthermore, we conducted hyperparameter search and optimization to explore the optimal network architecture and parameter configuration, resulting in a model with compelling performance.
# Even though the model seems to work well on most types of network attacks, it fails to correctly identify infiltration attacks, misclassifiying `77%` of all infiltration traffic as benign traffic. This could be explained by the simmilarity of feature statistics observed in these two kinds of network traffic.
# As a result, other approaches to reliably detect infiltration attacks have to be explored.
